# %% [markdown]
# <a href="https://colab.research.google.com/github/smdimasarif/Pemograman-Dasar/blob/main/Pertemuan_1_Dimas_ARIF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Dimas arif"
umur = 20
jurusan = "RPE"
semester = 3
matakuliah = 'Pemograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Dimas arif
# 20
# RPE
# 3
# Pemograman Dasar
# False
